# %% [markdown]
# Weekly Challenge!
# Pretend the following problem was given to you as a take home assessment.
# Complete it and comment with a link to the submission and I'll review it!
#
# Problem:
# You are climbing a staircase. It takes n steps to reach the top.
# Each time you can either climb 1 or 2 steps. In how many distinct ways can you climb to the top?
#
# Example 1:
# Input: n = 2
# Output: 2
# Explanation: There are two ways to climb to the top.
# 1. 1 step + 1 step
# 2. 2 steps
#
# Example 2:
# Input: n = 3
# Output: 3
# Explanation: There are three ways to climb to the top.
# 1. 1 step + 1 step + 1 step
# 2. 1 step + 2 steps
# 3. 2 steps + 1 step

# %% [markdown]
# ![Fib-2.jpg](attachment:Fib-2.jpg)

# %% [markdown]
# # Brute Force Solution

# %%
# What is the minimum number of steps that can be taken?
minimum_step_size = int(input('minimum number of steps that can be taken: '))

# What is the maximum number of steps that can be taken?
maximum_step_size = int(input('maximum number of steps that can be taken: '))

# How many steps to the top of the staircase?
steps_to_top = int(input('How many steps to the top of the staircase '))

def factorial(n,m=1):
    # Negative numbers equates to going downstairs.
    # In such a case, the math is the same.
    n = abs(n)
    if n <= 1:
        return 1
    else:
        x = 1
        for i in range(m+1,n+1):
            x *= i
        return x
    
# For This Example
# minimum number of steps that can be taken:  1
# maximum number of steps that can be taken:  3
# How many steps to the top of the staircase  9
# Out:
# minimum number of steps that can be taken:  1
# maximum number of steps that can be taken:  3
# How many steps to the top of the staircase  9

# %%
# How many of the minimum step size is require to reach the top
count_minimum_step_size = int(steps_to_top / minimum_step_size)

# What is the maximum number of maximum step sizes can be made without overreaching the top
count_maximum_step_size = int(steps_to_top / maximum_step_size)

# How many minimum step sizes have to be removed per maximum step size
min_max_steps_ratio = int(round(maximum_step_size/minimum_step_size))

# Start with the maximum number of minimum steps
total_count_of_numbers_in_permutation = count_minimum_step_size

m = 0
x = 0
print("count_minimum_step_size: ", count_minimum_step_size)
print("count_maximum_step_size: ", count_maximum_step_size)
print("min_max_steps_ratio: ", min_max_steps_ratio)
# Out:
# count_minimum_step_size:  9
# count_maximum_step_size:  3
# min_max_steps_ratio:  3

# %%
while m <= count_maximum_step_size:
    x += factorial(total_count_of_numbers_in_permutation,count_minimum_step_size) / factorial(m)
    m += 1
    count_minimum_step_size -= min_max_steps_ratio 
    total_count_of_numbers_in_permutation = count_minimum_step_size + m
print("answer = ", x)
# Out:
# answer =  19.0

# %% [markdown]
# # Efficient Solution For Stated Problem

# %%
# The solution follows a fibonacci sequence

fib = [1,1]
n = int(input('How many steps to the top of the staircase '))

for i in range(2, n+1):
    fib.append(fib[i - 1] + fib[i - 2])
               
fib[n]

# For This Example
# Steps to the top of the staircase  12
# Out:
# How many steps to the top of the staircase  12
# 233
